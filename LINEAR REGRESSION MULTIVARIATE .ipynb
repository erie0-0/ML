# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.randn(100,1)*10
noise  = np.random.randn(100,1)
y = 4*X**3 +3*X + 1 + 5*noise

# %%
print(X.shape,y.shape)
# Out:
# (100, 1) (100, 1)

# %%
plt.title("Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X,y,c="orange")
plt.show()

# %%
# Add a bias term to X (X0 = 1)
X_b = np.c_[np.ones((100, 1)), X]
print(X_b.shape, y.shape)
# Out:
# (100, 2) (100, 1)

# %%
def model(X,Y,learning_rate, iteration):
    m = Y.size
    theta = np.zeros((X.shape[1],1))
    for iteration in range(iterations): 
        y_pred = np.dot(X,theta)
        cost = (1/(2*m))*np.sum(np.square(y_pred - Y))
        d_theta = (1/m)*np.dot(X.T,y_pred-Y)
        theta = theta - learning_rate*d_theta
    return theta

# %%
learning_rate = 0.005
iterations = 100

theta = model(X_b, y,learning_rate = learning_rate,iteration = iterations)

# %%
theta
# Out:
# array([[-196.3561488 ],
#        [1094.74677587]])

# %%
plt.scatter(X, y)
plt.plot(X,np.dot(X_b,theta), color='red')
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression using Gradient Descent Multivariate")
plt.show()

# %%
# Model Evaluation
def r2Score(y,yp):
    ymean = y.mean()
    num = np.sum((y-yp))**2
    denom = np.sum((y - ymean)**2)
    return 1 - num/denom 

r2Score(y,np.dot(X_b,theta))
# Out:
# 0.9369566531901867
